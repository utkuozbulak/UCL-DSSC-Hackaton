# %%
from azureml import Workspace

ws = Workspace()
ds = ws.datasets['Clean_Selected_Assets.csv']
dsRef = ws.datasets['germanRefugeeClean.csv']
mainframe = ds.to_dataframe()
refFrame = dsRef.to_dataframe()

# %%
mainframe.head(20)
# Out:
#           Date  BA/ LN Equity  LMT US Equity  GD US Equity  RTN US Equity  \
# 0   2007-01-03         433.00          91.93         73.95          52.11
# 1   2007-01-04         428.00          91.69         74.42          51.33
# 2   2007-01-05         423.50          92.02         74.59          51.63
# 3   2007-01-08         419.75          93.69         78.00          51.10
# 4   2007-01-09         419.00          93.60         78.31          51.59
# 5   2007-01-10         413.00          94.58         79.29          52.01
# 6   2007-01-11         421.25          95.66         80.51          52.20
# 7   2007-01-12         417.25          96.31         80.09          51.78
# 8   2007-01-16         430.00          97.00         79.66          51.78
# 9   2007-01-17         428.00          96.50         80.07          51.68
# 10  2007-01-18         428.50          96.80         78.86          51.56
# 11  2007-01-19         429.50          97.27         79.53          52.30
# ...

# %%
from datetime import datetime
refList = []
for row in mainframe:
    for rrow in refFrame:
        print(row)
#         mdate = datetime.strptime(row["date"], '%Y-%m-%d')
#         rdate = datetime.strptime(rrow["date"], '%Y-%m-%d')
#         if mdate-rdate > -31 and mdate-rdate<1:
#            refList.append(rrow["Value"])
# Out:
# Date
# Date
# BA/ LN Equity
# BA/ LN Equity
# LMT US Equity
# LMT US Equity
# GD US Equity
# GD US Equity
# RTN US Equity
# RTN US Equity
# NOC US Equity
# NOC US Equity
# Index
# Index
