# %%
from azureml import Workspace
# %matplotlib inline

import matplotlib.pyplot as plt
ws = Workspace()
ds = ws.datasets['refugeeClean.csv']
frame = ds.to_dataframe()
# Out:
# /home/nbuser/anaconda3_23/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/nbuser/anaconda3_23/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
frame[(frame['date'] > '2006-12-01')]
# Out:
#            date   Value
# 0    2007-01-01   25537
# 1    2007-02-01   23945
# 2    2007-03-01   25895
# 3    2007-04-01   23879
# 4    2007-05-01   23968
# 5    2007-06-01   23105
# 6    2007-07-01   23584
# 7    2007-08-01   25400
# 8    2007-09-01   25768
# 9    2007-10-01   30028
# 10   2007-11-01   28124
# 11   2007-12-01   26538
# 12   2008-01-01   29032
# 13   2008-02-01   27330
# 14   2008-03-01   25341
# 15   2008-04-01   27192
# 16   2008-05-01   26905
# 17   2008-06-01   27676
# 18   2008-07-01   31787
# 19   2008-08-01   31296
# 20   2008-09-01   35574
# 21   2008-10-01   36640
# 22   2008-11-01   32380
# 23   2008-12-01   32659
# 24   2009-01-01   31372
# 25   2009-02-01   29733
# 26   2009-03-01   31867
# 27   2009-04-01   30196
# 28   2009-05-01   29200
# 29   2009-06-01   30711
# ..          ...     ...
# 76   2013-05-01   46667
# 77   2013-06-01   48806
# 78   2013-07-01   52105
# 79   2013-08-01   49794
# 80   2013-09-01   56558
# 81   2013-10-01   59882
# ...

# %%
from datetime import datetime
import numpy as np
a=frame["date"]
date_list = []
for b in a:
    date_list.append(datetime.strptime(b,"%Y-%m-%d"))
plt.plot(date_list, frame["Value"])
